# %% [markdown]
# ## This chunking with the recursive text splitter

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter


para="""Artificial intelligence (AI) is technology that enables computers and machines to simulate human learning, comprehension, problem solving, decision making, creativity and autonomy.

Applications and devices equipped with AI can see and identify objects. They can understand and respond to human language. They can learn from new information and experience. They can make detailed recommendations to users and experts. They can act independently, replacing the need for human intelligence or intervention (a classic example being a self-driving car).

But in 2024, most AI researchers, practitioners and most AI-related headlines are focused on breakthroughs in generative AI (gen AI), a technology that can create original text, images, video and other content. To fully understand generative AI, it’s important to first understand the technologies on which generative AI tools are built: machine learning (ML) and deep learning.

Machine learning
A simple way to think about AI is as a series of nested or derivative concepts that have emerged over more than 70 years:Directly underneath AI, we have machine learning, which involves creating models by training an algorithm to make predictions or decisions based on data. It encompasses a broad range of techniques that enable computers to learn from and make inferences based on data without being explicitly programmed for specific tasks.

There are many types of machine learning techniques or algorithms, including linear regression, logistic regression, decision trees, random forest, support vector machines (SVMs), k-nearest neighbor (KNN), clustering and more. Each of these approaches is suited to different kinds of problems and data.

But one of the most popular types of machine learning algorithm is called a neural network (or artificial neural network). Neural networks are modeled after the human brain's structure and function. A neural network consists of interconnected layers of nodes (analogous to neurons) that work together to process and analyze complex data. Neural networks are well suited to tasks that involve identifying complex patterns and relationships in large amounts of data.

The simplest form of machine learning is called supervised learning, which involves the use of labeled data sets to train algorithms to classify data or predict outcomes accurately. In supervised learning, humans pair each training example with an output label. The goal is for the model to learn the mapping between inputs and outputs in the training data, so it can predict the labels of new, unseen data."""


text=RecursiveCharacterTextSplitter(chunk_size=100,chunk_overlap=20,length_function =len)


chunk=text.split_text(para)

for i, chunk in enumerate(chunk):
    print(f"Chunk {i+1}: {chunk}")
# Out:
# Chunk 1: Artificial intelligence (AI) is technology that enables computers and machines to simulate human
# Chunk 2: to simulate human learning, comprehension, problem solving, decision making, creativity and
# Chunk 3: creativity and autonomy.
# Chunk 4: Applications and devices equipped with AI can see and identify objects. They can understand and
# Chunk 5: can understand and respond to human language. They can learn from new information and experience.
# Chunk 6: and experience. They can make detailed recommendations to users and experts. They can act
# Chunk 7: They can act independently, replacing the need for human intelligence or intervention (a classic
# Chunk 8: (a classic example being a self-driving car).
# Chunk 9: But in 2024, most AI researchers, practitioners and most AI-related headlines are focused on
# Chunk 10: are focused on breakthroughs in generative AI (gen AI), a technology that can create original text,
# Chunk 11: original text, images, video and other content. To fully understand generative AI, it’s important
# Chunk 12: AI, it’s important to first understand the technologies on which generative AI tools are built:
# Chunk 13: AI tools are built: machine learning (ML) and deep learning.
# Chunk 14: Machine learning
# Chunk 15: A simple way to think about AI is as a series of nested or derivative concepts that have emerged
# Chunk 16: that have emerged over more than 70 years:Directly underneath AI, we have machine learning, which
# Chunk 17: learning, which involves creating models by training an algorithm to make predictions or decisions
# Chunk 18: or decisions based on data. It encompasses a broad range of techniques that enable computers to
# Chunk 19: enable computers to learn from and make inferences based on data without being explicitly
# Chunk 20: being explicitly programmed for specific tasks.
# Chunk 21: There are many types of machine learning techniques or algorithms, including linear regression,
# Chunk 22: linear regression, logistic regression, decision trees, random forest, support vector machines
# Chunk 23: vector machines (SVMs), k-nearest neighbor (KNN), clustering and more. Each of these approaches is
# Chunk 24: these approaches is suited to different kinds of problems and data.
# Chunk 25: But one of the most popular types of machine learning algorithm is called a neural network (or
# Chunk 26: neural network (or artificial neural network). Neural networks are modeled after the human brain's
# Chunk 27: the human brain's structure and function. A neural network consists of interconnected layers of
# Chunk 28: layers of nodes (analogous to neurons) that work together to process and analyze complex data.
# Chunk 29: complex data. Neural networks are well suited to tasks that involve identifying complex patterns
# Chunk 30: complex patterns and relationships in large amounts of data.
# Chunk 31: The simplest form of machine learning is called supervised learning, which involves the use of
# Chunk 32: involves the use of labeled data sets to train algorithms to classify data or predict outcomes
# Chunk 33: or predict outcomes accurately. In supervised learning, humans pair each training example with an
# Chunk 34: example with an output label. The goal is for the model to learn the mapping between inputs and
# Chunk 35: between inputs and outputs in the training data, so it can predict the labels of new, unseen data.

# %% [markdown]
# ## this is the TExt splitter with sentence text splitter

# %%
# 
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import Document

# If para is a single string:
documents = [Document(text=para)]
# Initialize the splitter
splitter = SentenceSplitter(
    chunk_size=102,  # Maximum number of tokens per chunk
    chunk_overlap=20  # Number of overlapping tokens between chunks
)

# Pass documents or raw text to get nodes/chunks
nodes = splitter.get_nodes_from_documents(documents)

print(nodes)
# Out:
# [TextNode(id_='8db9c296-1c30-49e3-b8e8-f2abcda70468', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='99151e51-de0b-4f84-996a-70aabbaf29bd', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='e41d201cae25ff37c284d97b5c2cf0d273062da38865bbc71e9bebe229d39c65')}, metadata_template='{key}: {value}', metadata_separator='\n', text="Artificial intelligence (AI) is technology that enables computers and machines to simulate human learning, comprehension, problem solving, decision making, creativity and autonomy.\n\nApplications and devices equipped with AI can see and identify objects. They can understand and respond to human language. They can learn from new information and experience. They can make detailed recommendations to users and experts. They can act independently, replacing the need for human intelligence or intervention (a classic example being a self-driving car).\n\nBut in 2024, most AI researchers, practitioners and most AI-related headlines are focused on breakthroughs in generative AI (gen AI), a technology that can create original text, images, video and other content. To fully understand generative AI, it’s important to first understand the technologies on which generative AI tools are built: machine learning (ML) and deep learning.\n\nMachine learning\nA simple way to think about AI is as a series of nested or derivative concepts that have emerged over more than 70 years:Directly underneath AI, we have machine learning, which involves creating models by training an algorithm to make predictions or decisions based on data. It encompasses a broad range of techniques that enable computers to learn from and make inferences based on data without being explicitly programmed for specific tasks.\n\nThere are many types of machine learning techniques or algorithms, including linear regression, logistic regression, decision trees, random forest, support vector machines (SVMs), k-nearest neighbor (KNN), clustering and more. Each of these approaches is suited to different kinds of problems and data.\n\nBut one of the most popular types of machine learning algorithm is called a neural network (or artificial neural network). Neural networks are modeled after the human brain's structure and function. A neural network consists of interconnected layers of nodes (analogous to neurons) that work together to process and analyze complex data. Neural networks are well suited to tasks that involve identifying complex patterns and relationships in large amounts of data.\n\nThe simplest form of machine learning is called supervised learning, which involves the use of labeled data sets to train algorithms to classify data or predict outcomes accurately. In supervised learning, humans pair each training example with an output label. The goal is for the model to learn the mapping between inputs and outputs in the training data, so it can predict the labels of new, unseen data.", mimetype='text/plain', start_char_idx=0, end_char_idx=2570, text_template='{metadata_str}\n\n{content}')]
